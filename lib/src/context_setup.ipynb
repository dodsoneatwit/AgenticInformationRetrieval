# %%
# Standard library imports
import os
import re
import math
import json
from collections import Counter

# Third-party library imports
import numpy as np
import pandas as pd
from datasets import load_dataset
from dotenv import load_dotenv
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# LangChain imports
from langchain.schema import Document
from langchain_pinecone import PineconeVectorStore, Pinecone
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import OpenAIEmbeddings

# Setup stop words for NLP
stop_words = set(stopwords.words('english'))

# %%
# process .env file
load_dotenv()
# Out:
# True

# %%
# Access the environment variables
openai_api_key = os.getenv('OPENAI_KEY')
pinecone_api_key = os.getenv('PINECONE_API_KEY')
pc_index = os.getenv('PINECONE_CONTEXT')

# %%
# function for tokenization and special character and stopword removal
def clean(data):
    # regex removes punctuation and special characters
    no_punctuation_and_specials = re.sub(r'[^\w\s]', '', str(data))

    # tokenizing step
    tokens = word_tokenize(str(no_punctuation_and_specials))

    # stopword removal
    filtered_tokens = [str(word) for word in tokens if word.lower() not in stop_words]

    # returns tokenized text in sentence format
    return " ".join(filtered_tokens)

# %%
# general function for preprocessing data
def preprocess(data):
    # includes only needed columns
    data = data[['passage']]
    data.loc[:,'passage'] = data['passage'].apply(clean) # applies preprocessing function
    data = data.reset_index(drop=True)
    data.columns = ['Passage'] # renames column names
    return data

# %%
embeddings = OpenAIEmbeddings()

# %%
documents = []
rag_dataset = load_dataset("rag-datasets/rag-mini-wikipedia", "text-corpus", split='passages')
unpreprocessed_dataset = pd.DataFrame(rag_dataset)

unpreprocessed_dataset.head()
# Out:
#                                              passage  id
# 0  Uruguay (official full name in  ; pron.  , Eas...   0
# 1  It is bordered by Brazil to the north, by Arge...   1
# 2  Montevideo was founded by the Spanish in the e...   2
# 3  The economy is largely based in agriculture (m...   3
# 4  According to Transparency International, Urugu...   4

# %%
complete_dataset = preprocess(unpreprocessed_dataset)
complete_dataset
# Out:
#                                                 Passage
# 0     Uruguay official full name pron Eastern Republ...
# 1     bordered Brazil north Argentina across bank Ur...
# 2     Montevideo founded Spanish early 18th century ...
# 3     economy largely based agriculture making 10 GD...
# 4     According Transparency International Uruguay s...
# ...                                                 ...
# 3195  2007 duck Tallahassee Florida survived gunshot...
# 3196  rare genetic mutation sees ducks born four leg...
# 3197  Moche people ancient Peru worshipped nature Be...
# 3198                    Angel Wing disease common ducks
# 3199  modern illustrated guide identification US wat...
#
# [3200 rows x 1 columns]

# %%
for index, row in complete_dataset.iterrows():
    documents.append(Document(
        page_content=f"{index + 1}. Passage: {row['Passage']}"
    ))

# %%
documents
# Out:
# [Document(metadata={}, page_content='1. Passage: Uruguay official full name pron Eastern Republic Uruguay country located southeastern part South America home 33 million people 17 million live capital Montevideo metropolitan area'),
#  Document(metadata={}, page_content='2. Passage: bordered Brazil north Argentina across bank Uruguay River west estuary RÃo de la Plata southwest South Atlantic Ocean southeast second smallest independent country South America larger Suriname French overseas department French Guiana'),
#  Document(metadata={}, page_content='3. Passage: Montevideo founded Spanish early 18th century military stronghold Uruguay independence 1828 following threeway struggle Spain Argentina Brazil constitutional democracy president fulfills roles head state head government'),
#  Document(metadata={}, page_content='4. Passage: economy largely based agriculture making 10 GDP substantial export statesector relies heavily world trade Consequently badly affected downturn global prices However economy whole stable surrounding states maintains solid reputation investors'),
#  Document(metadata={}, page_content='5. Passage: According Transparency International Uruguay second least corrupt country Latin America Chile Transparencyorg political labor conditions among freest continent'),
#  Document(metadata={}, page_content='6. Passage: November 2007 became first Latin American country second American Continent recognize samesex civil unions national level Uruguay Passes CivilUnion Law San Francisco Bay Times December 6 2007'),
#  Document(metadata={}, page_content='7. Passage: 88 population European descent twothirds population declared Roman Catholics However majority Uruguayans nominally religious CIA World Factbook Uruguay'),
#  Document(metadata={}, page_content='8. Passage: name Uruguay comes GuaranÃ many possible meanings proposed meanings'),
#  Document(metadata={}, page_content='9. Passage: River colorful painted chinchillas birds poetic interpretation attributed Juan Zorrilla de San MartÃn'),
#  Document(metadata={}, page_content='10. Passage: River bring food anonymous version popularized since discovery old document written Jesuit Lucas Marton'),
#  Document(metadata={}, page_content='11. Passage: inhabitants Uruguay European colonization area various tribes hunter gatherer native Americans well known CharrÃºa Indians small tribe driven south GuaranÃ Indians Paraguay population estimated 5000 10000 ref'),
#  Document(metadata={}, page_content='12. Passage: Plaza Independencia Independence Square Montevideo hosts tomb JosÃ Artigas late leader Provincia Oriental Liga Federal front square Palacio Salvo seen'),
#  Document(metadata={}, page_content='13. Passage: Europeans arrived territory presentday Uruguay year 1536 absence gold silver limited settlement region 16th 17th centuries Uruguay became zone contention Spanish Portuguese empires 1603 Spanish began introduce cattle became source wealth region ref first permanent settlement territory presentday Uruguay founded Spanish 1624 Villa Soriano southwestern coast RÃo Negro 1680 Portuguese built fort Colonia del Sacramento ref Spanish colonization increased Spain sought limit Portugals expansion Brazils frontiers'),
#  Document(metadata={}, page_content='14. Passage: Another segment colonial Uruguays population consisted people African descent Colonial Uruguays African community grew number members escaped harsh treatment Buenos Aires Many relocated Montevideo larger black community seemed lest hostile politically Buenos Aires favorable climate lower humidity'),
#  Document(metadata={}, page_content='15. Passage: province Viceroyalty La Plata colonial Uruguay known Banda Oriental Eastern Strip referring location east Rio Uruguay inhabitants called Easterners Orientales term still commonly use refer'),
#  Document(metadata={}, page_content='16. Passage: Uruguays capital Montevideo founded Spanish early 18th century military stronghold natural harbor soon developed commercial center competing Argentinas capital Buenos Aires Uruguays early 19th century history shaped ongoing conflicts British Spanish Portuguese colonial forces dominance ArgentinaBrazilUruguay region ref 1806 1807 British army attempted seize Buenos Aires part war Spain result beginning 1807 Montevideo occupied 10000strong British force held middle year left attack Buenos Aires'),
#  Document(metadata={}, page_content='17. Passage: Uruguayans road independence much longer countries Americas Early efforts attaining independence focused overthrow Spanish rule process begun Jose Gervasio Artigas 1811 led forces victory Spanish battle Las Piedras May 18 1811 1816 Portuguese troops invaded presentday Uruguay led eventual annexation Brazil 1821 provincial name Provincia Cisplatina April 19 1825 thirtythree Uruguayan exiles led Juan Antonio Lavalleja returned Buenos Aires lead insurrection Uruguay help Argentine troops known Treinta Tres Orientales actions inspired representatives Uruguay meet La Florida town recently liberated area declared independence Portugal therefore Brazil August 25 1825 Uruguayan independence recognized neighbors 1828 Britain search new commercial markets brokered peace Argentina Brazil Uruguay ref'),
#  Document(metadata={}, page_content='18. Passage: RÃo de la Plata 1603'),
#  Document(metadata={}, page_content='19. Passage: Uruguays politics takes place framework presidential representative democratic republic whereby President Uruguay head state head government pluriform multiparty system Executive power exercised government Legislative power vested government two chambers General Assembly Uruguay Judiciary independent executive legislature'),
#  Document(metadata={}, page_content='20. Passage: Uruguays history Partido Colorado Partido Blanco alternated power Partido Blanco roots countryside original settlers Spanish origin cattle ranchers Partido Colorado roots port city Montevideo new immigrants Italian origin backing foreign interests Partido Colorado built welfare state financed taxing cattle revenue giving state pickles free services new urban immigrants became dependent state elections 2004 however brought Frente Amplio coalition socialists former Tupamaros former communists mainly social democrats among others power majorities houses parliament election President TabarÃ VÃzquez absolute majority'),
#  Document(metadata={}, page_content='21. Passage: Frente Amplio displaced Partido Colorado traditional urban welfare state constituency enjoying boom export commodity prices'),
#  Document(metadata={}, page_content='22. Passage: Reporters Without Borders worldwide press freedom index ranked Uruguay 57th 168 reported countries 2006 Reporters Without Borders Worldwide Press Freedom Index 2006'),
#  Document(metadata={}, page_content='23. Passage: According Freedom House American organization tracks global trends political freedom Uruguay ranked twentyseventh Freedom World index According Economist Intelligence Unit Uruguay scores 796 Democracy Index located last position among 28 countries considered Full Democracies world report looks 60 indicators across five categories Free elections civil liberties functioning government political participation political culture Economist world 2007 Pause democracys march Page 93'),
#  Document(metadata={}, page_content='24. Passage: Uruguay ranks 28th World CPI Corruption Perception Index composed Transparency International'),
#  Document(metadata={}, page_content='25. Passage: Uruguayan constitution allows citizens challenge laws approved Parliament use Referendum propose changes Constitution use Plebiscite last 15 years method used several times confirm amnesty members military violated human rights military regime 19731985 stop privatization public utilities companies See Economy Public Sector defend pensioners incomes protect water resources'),
#  Document(metadata={}, page_content='26. Passage: 176214 square kilometres 68036 square miles continental land 142199 square kilometres 54903 sq mi jurisdictional waters small river islands Instituto Nacional Estadistica Uruguay second smallest sovereign nation South America Suriname third smallest territory French Guiana smallest landscape features mostly rolling plains low hill ranges cuchillas fertile coastal lowland dense fluvial network covers country consisting four river basins deltas RÃo de la Plata Uruguay River Laguna MerÃn RÃo Negro major internal river RÃo Negro black river Several lagoons found along Atlantic coast'),
#  Document(metadata={}, page_content='27. Passage: highest point country Cerro Catedral 51366 meters 1685 ft 3 Sierra de CarapÃ mountain range southwest RÃo de la Plata estuary Uruguay River forms western border ParanÃ River run Uruguay'),
#  Document(metadata={}, page_content='28. Passage: Uruguay consists nineteen departments singular first departments formed 1816 newest date 1885 Flores departments governed intendente municipal elected five years members Departmental Assembly form legislative level department'),
#  Document(metadata={}, page_content='29. Passage: Map Uruguay'),
#  Document(metadata={}, page_content='30. Passage: Uruguay shares borders two countries Argentina'),
#  Document(metadata={}, page_content='31. Passage: Brazil'),
#  Document(metadata={}, page_content='32. Passage: climate Uruguay temperate warm summers cold winters predominantly gently undulating landscape also somewhat vulnerable rapid changes weather fronts'),
#  Document(metadata={}, page_content='33. Passage: receives periodic influence polar air winter tropical air Brazil summer Without mountains zone act barrier air masses freely move territory causing abrupt weather changes'),
#  Document(metadata={}, page_content='34. Passage: coolest month June warmest January rainfall equally distributed throughout year tends bit frequent autumn months frequent thunderstorms summer Although snow common snowed 1913 1918 1963 1989 1992 2007'),
#  Document(metadata={}, page_content='35. Passage: Playa Brava Punta del Este Uruguay'),
#  Document(metadata={}, page_content='36. Passage: Since 1984 Uruguay Antarctic base General Artigas King George Island Antarctica part South Shetland Islands archipelago 100 km 62 mi Antarctic peninsula'),
#  Document(metadata={}, page_content='37. Passage: Montevideo Uruguays capital'),
#  Document(metadata={}, page_content='38. Passage: Uruguay middle income economy mainly dominated State services sector exportoriented agricultural sector industrial sector Uruguay relies heavily trade particularly agricultural exports leaving country particularly vulnerable slumps commodity prices global economic slowdowns averaging growth 5 annually 19961998 19992001 economy suffered lower demand Argentina Brazil together account nearly half Uruguays exports Despite severity trade shocks Uruguays financial indicators remained stabler neighbours reflection solid reputation among investors investmentgrade sovereign bond rating â one two South America Aboutcom Go South America based information CIA World Factbook recent years Uruguay shifted energy developing commercial use technologies become first exporter software Latin America Diego Stewart Building Uruguay exports architectural services India Latin America Latin Trade May 2005 Retrieved August 11 2007'),
#  Document(metadata={}, page_content='39. Passage: parts economy appeared resilient downturn severe impact local population Unemployment levels rose 20 real wages fell peso devalued worsening economic conditions played part turning public opinion mildly free market economic policies adopted previous administrations 1990s leading popular rejection proposals privatization state petroleum company 2003 state water company 2004 newly elected Frente Amplio government pledging continue payments Uruguays external debt Michael Fox Uruguays Frente Amplio Revolution Dilution June 19 2007 Retrieved August 11 2007 also promised undertake Emergency Plan See sectionSocial Problems Poverty inequality attack widespread problems poverty unemployment See leaders President Tabare Vazquez taking office announced 100m emergency plan help poor'),
#  Document(metadata={}, page_content='40. Passage: Agriculture played important part Uruguayan history national identity middle twentieth century entire country sometimes likened single huge estancia agricultural estate centred around Montevideo wealth generated hinterland spent casco administrative head'),
#  Document(metadata={}, page_content='41. Passage: heartland historic estancias Estancia San Eugenio CasupÃ southern department Florida'),
#  Document(metadata={}, page_content='42. Passage: Today agriculture contributes roughly 10 countryâs GDP still main foreign exchange earner putting Uruguay line agricultural exporters like Brazil Canada New Zealand Uruguay member Cairns Group exporters agricultural products Uruguayâs agriculture relatively low inputs labour technology capital comparison countries results comparatively lower yields per hectare also opens door Uruguay market products natural ecological'),
#  Document(metadata={}, page_content='43. Passage: Campaigns like âUruguayan grassfed beefâ âUruguay Naturalâ aim establish Uruguay premium brand beef wine food products'),
#  Document(metadata={}, page_content='44. Passage: Recently industry developed around estancia tourism capitalizes traditional folkloristic connotations associated gaucho culture remaining resources Uruguays historic estancias'),
#  Document(metadata={}, page_content='45. Passage: Approximately 88 population prevalently white European descent Spaniards followed closely Italians French Germans Portuguese British Swiss Russians Poles Bulgarians Hungarians Ukrainians Lithuanians Estonians Latvians Dutch Belgians Croatians Greeks Scandinavians Irish Armenians 08 Mestizo'),
#  Document(metadata={}, page_content='46. Passage: remaining AfroLatin American ancestry ref'),
#  Document(metadata={}, page_content='47. Passage: INE Spanish'),
#  Document(metadata={}, page_content='48. Passage: Many European immigrants arrived Uruguay late 1800s heavily influenced architecture culture Montevideo major cities reason Montevideo life within city reminiscent parts Europe example Barcelona Thessaloniki TelAviv said similar Montevideo different aspects ref'),
#  Document(metadata={}, page_content='49. Passage: colonies Colonia Valdense Waldensian colony Colonia Suiza also named Nueva Helvecia mainly Swiss colony German Austrian settlers founded department Colonia also towns founded early British settlers like Conchillas Barker Russian colony called San Javier found department RÃo Negro Mennonite colonies also found department RÃo Negro department Canelones One called El OmbÃº famous wellknown Dulce de Leche Claldy located near city Young'),
#  Document(metadata={}, page_content='50. Passage: Uruguay large urban middle class literacy rate 9679 1996 est ref 1970s 1980s estimated 600000 Uruguayans emigrated mainly Spain Italy Argentina Brazil Uruguayans went various countries Europe USA Australia'),
#  Document(metadata={}, page_content='51. Passage: birth rate 1673 births1000 population Brazil 1656 births1000 population ref'),
#  Document(metadata={}, page_content='52. Passage: Uruguays oldest church San Carlos Maldonado'),
#  Document(metadata={}, page_content='53. Passage: Church state officially separated since approximately 1916 Uruguayans adhere Roman Catholic faith 62 smaller Protestant 4 Jewish 3 well large nonprofessing group 31'),
#  Document(metadata={}, page_content='54. Passage: Although majority Uruguayans actively practice religion nominally church members Catholic Protestant Jewish communities widely considered secular nation Latin America'),
#  Document(metadata={}, page_content='55. Passage: According data published United Nations Gini index Uruguay equals 448 2003 100 stands maximum inequality 0 even distribution wealth population'),
#  Document(metadata={}, page_content='56. Passage: recent report compiled published National Statistics Institute Instituto Nacional de Estadistica Uruguay used 2 indicators estimate number people living poverty country'),
#  Document(metadata={}, page_content='57. Passage: Indigence line income family enough basic food consumption'),
#  Document(metadata={}, page_content='58. Passage: Poverty line income family enough food consumption clothing health transport'),
#  Document(metadata={}, page_content='59. Passage: numbers obtained depends according methodology used inform uses 3 different methods According one proposed Regional Workshop poverty measurement 1996 produces highest values results first quarter 2006'),
#  Document(metadata={}, page_content='60. Passage: Population Indigence line 301'),
#  Document(metadata={}, page_content='61. Passage: Population Poverty line 18'),
#  Document(metadata={}, page_content='62. Passage: reports shows indicators improving country recovering last 2002 crisis 2004 poverty indicators reached time high ref'),
#  Document(metadata={}, page_content='63. Passage: new ministry Social Development created Broad Front Uruguay Frente Amplio government led Tabare Vazquez Emergency plan targets less favoured 200000 Uruguayans'),
#  Document(metadata={}, page_content='64. Passage: average income woman 2002 Uruguay 718 income men activity ref average income African heritage workers 65 European heritage ref'),
#  Document(metadata={}, page_content='65. Passage: Montevideo capital country view pedestrian street Ciudad Vieja former Spanish citadel'),
#  Document(metadata={}, page_content='66. Passage: Although rents neighborhoods high demand expensive Uruguay usually required another property warranty contract leave deposit many afford'),
#  Document(metadata={}, page_content='67. Passage: first condition makes renting property especially difficult least favoured sectors population According INE 23 3 population lives place neither owned rented proper built houses others precarious constructions built illegally public private empty land outside cities Thus whole new poor neighborhoods emerged last decades called Asentamientos colloquially Cantegriles ironic allusion fashionable Neighborhood Cantegril Punta del Este'),
#  Document(metadata={}, page_content='68. Passage: phenomena similar Favelas Brazil'),
#  Document(metadata={}, page_content='69. Passage: Villas Miseria Argentina Barrios Venezuela Arrabales Spain Poblaciones Callampa Chile Jacales Mexico'),
#  Document(metadata={}, page_content='70. Passage: main sport Uruguay football Uruguay national football team one five nations win FIFA World Cup two occasions 1930 Uruguay hosted first ever World Cup went win competition defeating Argentina 42 final Uruguay 1950 FIFA World Cup well famously defeating favored hosts Brazil 21 final Uruguay far smallest country population wise win World Cup World Cup winners nation second smallest population Argentina winners 1978 1986 editions currently 40000000 people according latest estimate 2002 census Uruguays current population slightly 3400000 Uruguay national team also Copa AmÃrica 14 different times record shares Argentina'),
#  Document(metadata={}, page_content='71. Passage: Basketball rugby union tennis popular sports Uruguay'),
#  Document(metadata={}, page_content='72. Passage: Political economic rankings'),
#  Document(metadata={}, page_content='73. Passage: Health rankings'),
#  Document(metadata={}, page_content='74. Passage: rankings'),
#  Document(metadata={}, page_content='75. Passage: Michael Faraday FRS September 22 1791 â August 25 1867 English chemist physicist natural philosopher terminology time contributed fields electromagnetism electrochemistry'),
#  Document(metadata={}, page_content='76. Passage: Faraday studied magnetic field around conductor carrying DC electric current established basis magnetic field concept physics discovered electromagnetic induction diamagnetism electrolysis established magnetism could affect rays light underlying relationship two phenomena Michael Faraday entry 1911 Encyclopaedia Britannica hosted LovetoKnow Retrieved January 2007 Institution Engineering Technology London Archives Michael Faraday inventions electromagnetic rotary devices formed foundation electric motor technology largely due efforts electricity became viable use technology'),
#  Document(metadata={}, page_content='77. Passage: chemist Faraday discovered benzene investigated clathrate hydrate chlorine invented early form bunsen burner system oxidation numbers popularized terminology anode cathode electrode ion'),
#  Document(metadata={}, page_content='78. Passage: Although Faraday received little formal education knew little higher mathematics calculus one influential scientists history historians science refer best experimentalist history science best experimentalist history science Quoting Dr Peter Ford University Bathâs Department Physics Accessed January 2007 SI unit capacitance farad named Faraday constant charge mole electrons 96485 coulombs Faradays law induction states magnetic field changing time creates proportional electromotive force'),
#  Document(metadata={}, page_content='79. Passage: Faraday first foremost Fullerian Professor Chemistry Royal Institution Great Britain position appointed life'),
#  Document(metadata={}, page_content='80. Passage: Michael Faraday photograph John Watkins British Library'),
#  Document(metadata={}, page_content='81. Passage: Michael Faraday born Newington Butts near presentday South London England family well father James member Sandemanian sect Christianity James Faraday come London ca 1790 Outhgill Westmorland village blacksmith young Michael Faraday one four children basic school educations largely educate Michael Faraday History Science Technology Houghton Mifflin Company 2004 Answerscom 4 June 2007 ref fourteen became apprenticed local bookbinder bookseller George Riebau sevenyear apprenticeship read many books including Isaac Watts Improvement Mind enthusiastically implemented principles suggestions contained therein developed interest science specifically electricity particular inspired book Conversations Chemistry Jane Marcet'),
#  Document(metadata={}, page_content='82. Passage: age twenty 1812 end apprenticeship Faraday attended lectures eminent English chemist physicist Humphry Davy Royal Institution Royal Society John Tatum founder City Philosophical Society Many tickets lectures given Faraday William Dance one founders Royal Philharmonic Society Afterwards Faraday sent Davy three hundred page book based notes taken lectures Davys reply immediate kind favorable Davy damaged eyesight accident nitrogen trichloride decided employ Faraday secretary John Payne one Royal Institutions assistants fired Sir Humphry Davy asked find replacement appointed Faraday Chemical Assistant Royal Institution March 1'),
#  Document(metadata={}, page_content='83. Passage: classbased English society time Faraday considered gentleman Davy went long tour continent 18135 valet wish go Faraday going Davys scientific assistant asked act Davys valet replacement could found Paris Davy failed find replacement Faraday forced fill role valet well assistant throughout trip Davys wife Jane Apreece refused treat Faraday equal making travel outside coach eat servants etc generally made Faraday miserable contemplated returning England alone giving science altogether trip however give access European scientific elite host stimulating ideas'),
#  Document(metadata={}, page_content='84. Passage: sponsor mentor John Mad Jack Fuller created Fullerian Professorship Chemistry Royal Institution'),
#  Document(metadata={}, page_content='85. Passage: Faraday devout Christian member small Sandemanian denomination offshoot Church Scotland later served two terms elder groups church'),
#  Document(metadata={}, page_content='86. Passage: Faraday married Sarah Barnard 18001879 June 2 1821 although would never children met attending Sandemanian church'),
#  Document(metadata={}, page_content='87. Passage: elected member Royal Society 1824 appointed director laboratory 1825 1833 appointed Fullerian professor chemistry institution life without obligation deliver lectures'),
#  Document(metadata={}, page_content='88. Passage: title page Chemical History Candle 1861'),
#  Document(metadata={}, page_content='89. Passage: Faradays earliest chemical work assistant Davy made special study chlorine discovered two new chlorides carbon also made first rough experiments diffusion gases phenomenon first pointed John Dalton physical importance fully brought light Thomas Graham Joseph Loschmidt succeeded liquefying several gases investigated alloys steel produced several new kinds glass intended optical purposes specimen one heavy glasses afterwards became historically important substance Faraday detected rotation plane polarisation light glass placed magnetic field also substance first repelled poles magnet also endeavoured success make general methods chemistry distinguished results subject special study popular exposition'),
#  Document(metadata={}, page_content='90. Passage: invented early form become Bunsen burner used almost universally science laboratories convenient source heat See page 127 Faradays Chemical Manipulation Instructions Students Chemistry 1827'),
#  Document(metadata={}, page_content='91. Passage: Faraday worked extensively field chemistry discovering chemical substances benzene called bicarburet hydrogen inventing system oxidation numbers liquefying gases chlorine 1820 Faraday reported first syntheses compounds made carbon chlorine C 2 H 6 C 2 H 4 published results following year Faraday also determined composition chlorine clathrate hydrate discovered Humphry Davy 1810'),
#  Document(metadata={}, page_content='92. Passage: Faraday also discovered laws electrolysis popularized terminology anode cathode electrode ion terms largely created William Whewell'),
#  Document(metadata={}, page_content='93. Passage: Faraday first report later came called metallic nanoparticles 1847 discovered optical properties gold colloids differed corresponding bulk metal probably first reported observation effects quantum size might considered birth nanoscience'),
#  Document(metadata={}, page_content='94. Passage: Faradays greatest work probably electricity magnetism first experiment recorded construction voltaic pile seven halfpence pieces stacked together seven disks sheet zinc six pieces paper moistened salt water pile decomposed sulphate magnesia first letter Abbott July 12 1812'),
#  Document(metadata={}, page_content='95. Passage: ImageFaraday photograph iijpgthumb200pxleftMichael Faraday holding glass bar type used 1845 show magnetism affect light Detail engraving Henry Adlard based earlier photograph Maull Polyblank ca 1857 See National Portrait Gallery UK'),
#  Document(metadata={}, page_content='96. Passage: 1821 soon Danish physicist chemist Hans Christian Ãrsted discovered phenomenon electromagnetism Davy British scientist William Hyde Wollaston tried failed design electric motor Faraday discussed problem two men went build two devices produce called electromagnetic rotation continuous circular motion circular magnetic force around wire wire extending pool mercury magnet placed inside would rotate around magnet supplied current chemical battery latter device known homopolar motor experiments inventions form foundation modern electromagnetic technology Faraday published results without acknowledging debt Wollaston Davy resulting controversy caused Faraday withdraw electromagnetic research several years'),
#  Document(metadata={}, page_content='97. Passage: stage also evidence suggest Davy may trying slow Faradayâs rise scientist natural philosopher known 1825 instance Davy set onto optical glass experiments progressed six years great results Davys death 1829 Faraday stopped fruitless tasks moved endeavors worthwhile Two years later 1831 began great series experiments discovered electromagnetic induction Joseph Henry likely discovered selfinduction months earlier may anticipated work Francesco Zantedeschi Italy 1829 1830'),
#  Document(metadata={}, page_content='98. Passage: Faradays breakthrough came wrapped two insulated coils wire around massive iron ring bolted chair found upon passing current one coil momentary current induced coil phenomenon known mutual induction iron ringcoil apparatus still display Royal Institution subsequent experiments found moved magnet loop wire electric current flowed wire current also flowed loop moved stationary magnet demonstrations established changing magnetic field produces electric field relation mathematically modelled Faradays law subsequently became one four Maxwell equations turn evolved generalization known today field theory'),
#  Document(metadata={}, page_content='99. Passage: Michael Faraday statue Savoy Place London'),
#  Document(metadata={}, page_content='100. Passage: Sculptor John Henry Foley RA'),
#  Document(metadata={}, page_content='101. Passage: Faraday later used principle construct electric dynamo ancestor modern power generators'),
#  Document(metadata={}, page_content='102. Passage: 1839 completed series experiments aimed investigating fundamental nature electricity Faraday used static batteries animal electricity produce phenomena electrostatic attraction electrolysis magnetism etc concluded contrary scientific opinion time divisions various kinds electricity illusory Faraday instead proposed single electricity exists changing values quantity intensity voltage charge would produce different groups phenomena'),
#  Document(metadata={}, page_content='103. Passage: Near end career Faraday proposed electromagnetic forces extended empty space around conductor idea rejected fellow scientists Faraday live see idea eventually accepted Faradays concept lines flux emanating charged bodies magnets provided way visualize electric magnetic fields mental model crucial successful development electromechanical devices dominated engineering industry remainder 19th century'),
#  Document(metadata={}, page_content='104. Passage: 1845 discovered phenomenon named diamagnetism called Faraday effect plane polarization linearly polarized light propagated material medium rotated application external magnetic field aligned propagation direction wrote notebook last succeeded illuminating magnetic curve line force magnetising ray light established magnetic force light related'),
#  Document(metadata={}, page_content='105. Passage: work static electricity Faraday demonstrated charge resided exterior charged conductor exterior charge influence anything enclosed within conductor exterior charges redistribute interior fields due cancel shielding effect used known Faraday cage'),
#  Document(metadata={}, page_content='106. Passage: Faraday excellent experimentalist conveyed ideas clear simple language However mathematical abilities extend far trigonometry simplest algebra James Clerk Maxwell took work Faraday others consolidated set equations lie base modern theories electromagnetic phenomena'),
#  Document(metadata={}, page_content='107. Passage: Michael Faraday meets Father Thames Punch July 21 1855'),
#  Document(metadata={}, page_content='108. Passage: Beyond scientific research areas chemistry electricity magnetism Royal Institution Faraday undertook numerous often timeconsuming service projects private enterprise British government work included investigations explosions mines expert witness court preparation highquality optical glass'),
#  Document(metadata={}, page_content='109. Passage: respected scientist nation strong maritime interests Faraday spent extensive amounts time projects construction operation light houses protecting bottoms ships corrosion'),
#  Document(metadata={}, page_content='110. Passage: Faraday also active would called environmental science engineering investigated industrial pollution Swansea consulted air pollution Royal Mint July 1855 Faraday wrote letter Times subject foul condition River Thames resulted oftreprinted cartoon Punch See also Great Stink'),
#  Document(metadata={}, page_content='111. Passage: Faraday assisted planning judging exhibits Great Exhibition 1851 London also advised National Gallery cleaning protection art collection served National Gallery Site Commission 1857'),
#  Document(metadata={}, page_content='112. Passage: Education another area service Faraday lectured topic 1854 Royal Institution 1862 appeared Public Schools Commission give views education Great Britain Faraday also weighed negatively publics fascination tableturning mesmerism seances chastising public nations educational system See Illustrated London News July 1853 Faradays comments'),
#  Document(metadata={}, page_content='113. Passage: 125px'),
#  Document(metadata={}, page_content='114. Passage: June 1832 University Oxford granted Faraday Doctor Civil Law degree honorary lifetime Faraday rejected knighthood twice refused become President Royal Society'),
#  Document(metadata={}, page_content='115. Passage: 1848 result representations Prince Consort Michael Faraday awarded grace favour house Hampton Court Surrey free expenses upkeep Master Masons House later called Faraday House No37 Hampton Court Road 1858 Faraday retired live Twickenham Museum Faraday Faraday House Accessed June 2006'),
#  Document(metadata={}, page_content='116. Passage: Faraday died house Hampton Court August 25 1867 turned burial Westminster Abbey memorial plaque near Isaac Newtons tomb Faraday interred Sandemanian plot Highgate Cemetery'),
#  Document(metadata={}, page_content='117. Passage: Michael Faradays grave Highgate Cemetery'),
#  Document(metadata={}, page_content='118. Passage: Faraday gave successful series lectures chemistry physics flames Royal Institution entitled Chemical History Candle one earlier Christmas lectures young people still given year 1827 1860 Faraday gave Christmas lecture record nineteen times'),
#  Document(metadata={}, page_content='119. Passage: Faraday refused participate production chemical weapons Crimean War citing ethical reasons'),
#  Document(metadata={}, page_content='120. Passage: statue Faraday stands Savoy Place London outside Institution Electrical Engineers'),
#  Document(metadata={}, page_content='121. Passage: recently built hall accommodation Brunel University named Faraday'),
#  Document(metadata={}, page_content='122. Passage: hall Loughborough University named Faraday 1960 Near entrance dining hall bronze casting depicts symbol electrical transformer inside hangs portrait Faradays honour'),
#  Document(metadata={}, page_content='123. Passage: Faradays picture printed British Â20 banknotes 1991 2001 Bank England Withdrawn Notes'),
#  Document(metadata={}, page_content='124. Passage: video game Chromehounds ThermoVision Device named Faraday'),
#  Document(metadata={}, page_content='125. Passage: former UK Faraday Atmospheric Research Station Antarctica named'),
#  Document(metadata={}, page_content='126. Passage: Faraday one eight foreign members French Academy Sciences'),
#  Document(metadata={}, page_content='127. Passage: Michael Faradays signature'),
#  Document(metadata={}, page_content='128. Passage: Faradays books exception Chemical Manipulation collections scientific papers transcriptions lectures See page 220 Hamiltons Life Discovery Michael Faraday Giant Scientific Revolution 2002 Since death Faradays diary published several large volumes letters Faradays journal travels Davy 1813 1815'),
#  Document(metadata={}, page_content='129. Passage: One day sir may tax Faradays reply William Gladstone British Minister Finance asked practical value electricity'),
#  Document(metadata={}, page_content='130. Passage: would cause view acknowledged scientific men would great service science would even get say yes conclusions would help clear future progress believe hesitate like thoughts disturbed Life Letters 2389'),
#  Document(metadata={}, page_content='131. Passage: Tyndall John Faraday Discoverer Longmans 1st ed 1868 2nd ed 1870'),
#  Document(metadata={}, page_content='132. Passage: Bence Jones Henry 1870 Life Letters Faraday 2 vols Longmans'),
#  Document(metadata={}, page_content='133. Passage: Gladstone J H 1872 Michael Faraday Macmillan'),
#  Document(metadata={}, page_content='134. Passage: British Electrical Allied Manufacturers Association 1931 Faraday R R Clark Ltd Edinburgh 1931'),
#  Document(metadata={}, page_content='135. Passage: Williams L Pearce 1971 Faraday Biography Simon Schuster'),
#  Document(metadata={}, page_content='136. Passage: Agassi Joseph 1971 Faraday Natural Philosopher Chicago University Chicago Press'),
#  Document(metadata={}, page_content='137. Passage: 150px'),
#  Document(metadata={}, page_content='138. Passage: Faraday LoveToKnow 1911 Britannica Online Encyclopedia'),
#  Document(metadata={}, page_content='139. Passage: Experimental Researches Electricity Michael Faraday Original text Biographical Introduction Professor John Tyndall 1914 Everyman edition'),
#  Document(metadata={}, page_content='140. Passage: Anders Celsius'),
#  Document(metadata={}, page_content='141. Passage: observatory Anders Celsius contemporary engraving'),
#  Document(metadata={}, page_content='142. Passage: Anders Celsius November 27 1701 April 25 1744 Swedish astronomer'),
#  Document(metadata={}, page_content='143. Passage: Celsius born Uppsala Sweden professor astronomy Uppsala University 1730 1744 traveled 1732 1735 visiting notable observatories Germany Italy France'),
#  Document(metadata={}, page_content='144. Passage: Nuremberg 1733 published collection 316 observations aurora borealis made others period 17161732 Paris advocated measurement arc meridian Lapland 1736 took part expedition organized purpose French Academy Sciences led French mathematician Pierre Louis Maupertuis'),
#  Document(metadata={}, page_content='145. Passage: Celsius founded Uppsala Astronomical Observatory 1741 1742 proposed Celsius temperature scale paper Royal Swedish Academy Sciences thermometer 100 freezing point water 0 boiling point scale reversed Carolus Linnaeus 1745 today Linnaeus thermometer'),
#  Document(metadata={}, page_content='146. Passage: Anders Celsius first perform publish careful experiments aiming definition international temperature scale scientific grounds Swedish paper Observations two persistent degrees thermometer reports experiments check freezing point independent latitude atmospheric pressure determined dependence boiling water atmospheric pressure excellent agreement modern data gave rule determination boiling point barometric pressure deviates certain standard pressure History Celsius temperature scale'),
#  Document(metadata={}, page_content='147. Passage: 1744 died tuberculosis Uppsala buried Old Uppsala Church'),
#  Document(metadata={}, page_content='148. Passage: Celsius crater Moon named'),
#  Document(metadata={}, page_content='149. Passage: Millard Fillmore January 7 1800 March 8 1874 thirteenth President United States serving 1850 1853 last member Whig Party hold office second Vice President assume Presidency upon death sitting President succeeding Zachary Taylor died acute gastroenteritis Fillmore never elected President serving Taylors term failed gain nomination Presidency Whigs 1852 presidential election four years later 1856 presidential election failed win election President Know Nothing Party Whig candidate'),
#  Document(metadata={}, page_content='150. Passage: Fillmore born log cabin Summerhill New York Nathaniel Phoebe Millard Fillmore second nine children eldest son Though Unitarian later life'),
#  Document(metadata={}, page_content='151. Passage: Fillmore descended Scottish Presbyterians fathers side English dissenters mothers first apprenticed fuller learn clothmaking trade also served home guard New York militia time struggled obtain education frontier conditions attending New Hope Academy six months'),
#  Document(metadata={}, page_content='152. Passage: fell love Abigail Powers later married February 26 1826 couple two children Millard Powers Fillmore Mary Abigail Fillmore Later Fillmore bought apprenticeship moved Buffalo New York continue studies admitted bar 1823 began law practice East Aurora 1834 formed law partnership Fillmore Hall becoming Fillmore Hall 1836 good friend Nathan K Hall would later serve cabinet Postmaster General would become one western New Yorks prestigious firms'),
#  Document(metadata={}, page_content='153. Passage: 1846 founded private University Buffalo today public State University New York Buffalo UB University Buffalo largest school New York state university system'),
#  Document(metadata={}, page_content='154. Passage: Engraving Millard FillmoreIn 1828 Fillmore elected New York State Assembly AntiMasonic ticket serving one term 1829 1831 later elected Whig followed mentor Thurlow Weed party 23rd Congress 1832 serving 1833 1835 reelected 1836 25th Congress 26th 27th Congresses serving total 1833 1843 declining candidate renomination 1842'),
#  Document(metadata={}, page_content='155. Passage: Congress opposed entrance Texas slave territory came second place bid Speaker House Representatives 1841 served chairman House Ways Means Committee 1841 1843 author Tariff 1842 well two bills President John Tyler vetoed'),
#  Document(metadata={}, page_content='156. Passage: leaving Congress Fillmore unsuccessful Whig candidate Governor New York 1844 served New York State Comptroller 1847 1849 state comptroller revised New Yorks banking system making model future National Banking System'),
#  Document(metadata={}, page_content='157. Passage: Whig national convention 1848 nomination Gen Zachary Taylor president angered supporters Henry Clay well opponents slavery extension territory gained USMexican War group practical Whig politicians nominated Fillmore vice president believing would heal party wounds help ticket carry New York state'),
#  Document(metadata={}, page_content='158. Passage: TaylorFillmore campaign posterHaving worked way Whig Party New York Fillmore selected Taylors running mate thought obscure selfmade candidate New York would complement Taylor slaveholding military man south'),
#  Document(metadata={}, page_content='159. Passage: Fillmore also selected part block New York state machine boss Thurlow Weed receiving vice presidential nomination front man William H Seward receiving position Taylors cabinet Weed ultimately got Seward elected senate competition Seward Fillmore led Sewards becoming vocal part cabinet meetings voice Fillmore advising administration battle would continue even Taylors death'),
#  Document(metadata={}, page_content='160. Passage: Taylor Fillmore disagreed slavery issue new western territories taken Mexico MexicanAmerican War Taylor wanted new states free states Fillmore supported slavery states means appeasing South words God knows detest slavery existing evil must endure give protection guaranteed Constitution'),
#  Document(metadata={}, page_content='161. Passage: Fillmore presided Senate months nervewracking debates Compromise 1850 one debate Senator Henry Foote Mississippi pulled pistol Senator Thomas Hart Benton Missouri Fillmore made public comment merits compromise proposals days President Taylors death Fillmore suggested president tie vote Henry Clays bill would vote favor North'),
#  Document(metadata={}, page_content='162. Passage: Official White House portrait Millard FillmoreFillmore ascended presidency upon sudden unexpected death President Taylor July 1850 change leadership also signaled abrupt political shift administration Fillmore removed Taylors entire cabinet replacing individuals known favorable Compromise efforts Fillmore signaled shift appointing Daniel Webster Secretary State'),
#  Document(metadata={}, page_content='163. Passage: president Fillmore dealt increasing party divisions within Whig party party harmony became one primary objectives tried unite party pointing differences Whigs Democrats proposing tariff reforms negatively reflected Democratic Party Another primary objective Fillmore preserve Union intensifying slavery debate'),
#  Document(metadata={}, page_content='164. Passage: Henry Clays proposed bill admit California Union still aroused violent arguments extension slavery without progress toward settling major issues South continued threaten secession Fillmore recognized Clays plan best way end sectional crisis California free state harsher fugitive slave law abolish slave trade DC Clay exhausted left Washington recuperate passing leadership Senator Stephen Douglas Illinois critical juncture President Fillmore announced support Compromise 1850'),
#  Document(metadata={}, page_content='165. Passage: August 6 1850 sent message Congress recommending Texas paid abandon claims part New Mexico helped shift critical number northern Whigs Congress away insistence upon Wilmot Provisoâthe stipulation land gained Mexican War must closed slavery'),
#  Document(metadata={}, page_content='166. Passage: Douglass effective strategy Congress combined Fillmores pressure gave impetus Compromise movement Breaking Clays single legislative package Douglas presented five separate bills Senate'),
#  Document(metadata={}, page_content='167. Passage: Admit California free state'),
#  Document(metadata={}, page_content='168. Passage: Settle Texas boundary compensate state lost lands'),
#  Document(metadata={}, page_content='169. Passage: Grant territorial status New Mexico'),
#  Document(metadata={}, page_content='170. Passage: Place federal officers disposal slaveholders seeking escapeesâthe Fugitive Slave Act'),
#  Document(metadata={}, page_content='171. Passage: Abolish slave trade District Columbia'),
#  Document(metadata={}, page_content='172. Passage: measure obtained majority September 20 President Fillmore signed law Webster wrote sleep nights'),
#  Document(metadata={}, page_content='173. Passage: Portrait Millard FillmoreWhigs sides refused accept finality Fillmores law led party division loss numerous elections forced Northern Whigs say God Save us Whig Vice Presidents'),
#  Document(metadata={}, page_content='174. Passage: Fillmores greatest difficulty fugitive slave law enforce without seeming show favor towards Southern Whigs solution appease northern southern Whigs calling enforcement fugitive slave law North enforcing South law forbidding involvement Cuba sole purpose adding slave state'),
#  Document(metadata={}, page_content='175. Passage: Another issue presented Fillmores presidency arrival Louis Kossuth exiled leader failed Hungarian revolution Kossuth wanted United States abandon nonintervention policies came European affairs recognize Hungaryâs independence problem came enormous support Kossuth received GermanAmerican immigrants United States essential reelection Whigs Democrats Fillmore refused change American policy decided remain neutral despite political implications neutrality would produce'),
#  Document(metadata={}, page_content='176. Passage: Another important legacy Fillmores administration sending Commodore Matthew C Perry open Japan Western trade though Perry reach Japan Franklin Pierce replaced Fillmore president'),
#  Document(metadata={}, page_content='177. Passage: Fillmore appointed following Justices Supreme Court United States'),
#  Document(metadata={}, page_content='178. Passage: northern Whigs remained irreconcilable refusing forgive Fillmore signed Fugitive Slave Act helped deprive Presidential nomination 1852 Within years apparent although Compromise intended settle slavery controversy served rather uneasy sectional truce'),
#  Document(metadata={}, page_content='179. Passage: Whig party deeply divided two leading candidates Whig party Webster Fillmore refused combine secure nomination Winfield Scott received north south refused unite behind Scott 4 31 states lost election Franklin Pierce'),
#  Document(metadata={}, page_content='180. Passage: Fillmores defeat Whig party continued downward spiral party division coming hands Kansas Nebraska Act emergence Know Nothing party'),
#  Document(metadata={}, page_content='181. Passage: Statue Fillmore outside City Hall downtown Buffalo New York'),
# ...
#  Document(metadata={}, page_content='956. Passage: 250px'),
#  Document(metadata={}, page_content='957. Passage: Penguins superbly adapted aquatic life wings become flippers useless flight air water however penguins astonishingly agile Within smooth plumage layer air preserved ensuring buoyancy air layer also helps insulate birds cold waters'),
#  Document(metadata={}, page_content='958. Passage: land penguins use tails wings maintain balance upright stance'),
#  Document(metadata={}, page_content='959. Passage: penguins countershaded white underside dark mostly black upperside camouflage predator looking orca leopard seal difficulty distinguishing white penguin belly reflective water surface dark plumage backs camouflages'),
#  Document(metadata={}, page_content='960. Passage: Diving penguins reach 6 12 kmh 37 75 mph though reports velocities 27 kmh 17 mph realistic case startled flight small penguins usually dive deep catch prey near surface dives normally last one two minutes Larger penguins dive deep case need Dives large Emperor Penguin recorded reach depth 565 1870 ft last 22 minutes'),
#  Document(metadata={}, page_content='961. Passage: Penguins either waddle feet slide bellies across snow movement called tobogganing conserves energy moving quickly also jump feet together want move quickly cross steep rocky terrain'),
#  Document(metadata={}, page_content='962. Passage: Penguins average sense hearing birds Wever et al 1969 used parents chicks locate one another crowded colonies Jouventin et al 1999 eyes adapted underwater vision primary means locating prey avoiding predators air suggested nearsighted although research supported hypothesis Sivak et al 1987'),
#  Document(metadata={}, page_content='963. Passage: Penguins thick layer insulating feathers designed keep warm water heat loss water much greater air Emperor penguin largest penguin largest body mass penguins reduces relative surface area heat loss also able control blood flow extremities reducing amount blood gets cold still keeping extremities freezing extreme cold Antarctic winter females sea fishing food leaving males brave weather often huddle together keep warm rotate positions make sure penguin gets turn center heat pack'),
#  Document(metadata={}, page_content='964. Passage: drink salt water supraorbital gland filters excess salt bloodstream salt excreted concentrated fluid nasal passages'),
#  Document(metadata={}, page_content='965. Passage: penguins mate life others one season generally raise small brood parents cooperate caring clutch young cold season hand mates separate several months protect egg Usually male stays egg keeps warm female goes sea find food baby female comes back switch roles'),
#  Document(metadata={}, page_content='966. Passage: mothers lose chick sometimes attempt steal another mothers chick usually unsuccessfully females vicinity assist defending mother keeping chick species Emperor Penguins young penguins assemble large groups called crÃches'),
#  Document(metadata={}, page_content='967. Passage: Isabelline AdÃlie penguin Gourdin Island December 2002'),
#  Document(metadata={}, page_content='968. Passage: Perhaps one 50000 penguins species born brown rather black plumage called Isabelline penguins possibly reference legend archduchess Isabella Austria vowed change undergarments husband united northern southern Low Countries taking city Ostendwhich took three years accomplish Isabellinism different albinism though faded color plumage calls albinism mind Isabelline penguins tend live shorter lives normal penguins well camouflaged deep often passed mates'),
#  Document(metadata={}, page_content='969. Passage: Updated Marples 1962 Acosta Hospitaleche 2004 Ksepka et al 2006 See gallery images living species'),
#  Document(metadata={}, page_content='970. Passage: ORDER SPHENISCIFORMES'),
#  Document(metadata={}, page_content='971. Passage: Taxonomy Clarke et al 2003 Ksepka et al 2006 apply phylogenetic taxon Spheniscidae referred Spheniscinae Furthermore restrict phylogenetic taxon Sphenisciformes flightless taxa establish Clarke et al 2003 phylogenetic taxon Pansphenisciformes equivalent Linnean taxon Sphenisciformes ie including flying basal protopenguins discovered eventually Given neither relationships penguin subfamilies placement penguins avian phylogeny presently resolved seems spurious case confusing established Linnean system thus followed'),
#  Document(metadata={}, page_content='972. Passage: evolutionary history penguins wellresearched represents showcase evolutionary biogeography though penguin bones one species vary much size good specimens known alpha taxonomy many prehistoric forms still leaves much desired seminal articles penguin prehistory published since 2005 Bertelli Giannini 2005 Baker et al 2006 Ksepka et al 2006 Slack et al 2006 evolution living genera considered resolved'),
#  Document(metadata={}, page_content='973. Passage: According comprehensive review available evidence Ksepka et al 2006 basal penguins lived around time CretaceousâTertiary extinction event somewhere general area southern New Zealand Byrd Land Antarctica Due plate tectonics areas time less apart rather today recent common ancestor penguins sister clade roughly dated CampanianMaastrichtian boundary around 7068 mya Baker et al 2006 Slack et al 2006 exact divergence dates according Baker et al 2006 mentioned section precisely resolved appears due uncertainties molecular clock used'),
#  Document(metadata={}, page_content='974. Passage: said certainly possible absence direct ie fossil evidence end Cretaceous penguin lineage must evolutionarily well distinct though much less morphologically fairly likely yet entirely flightless time flightless birds generally low resilience breakdown trophic webs follows initial phase mass extinctions belowaverage dispersal capabilities see also Flightless Cormorant'),
#  Document(metadata={}, page_content='975. Passage: oldest known fossil penguin species Waimanu manneringi lived early Paleocene epoch New Zealand 62 mya Slack et al 2006 well adapted aquatic life modern penguins Waimanu generally loonlike birds already flightless short wings adapted deep diving swam surface using mainly feet wings opposed diving birds living extinct already adapting underwater locomotion'),
#  Document(metadata={}, page_content='976. Passage: Perudyptes northern Peru dated 42 mya unnamed fossil Argentina proves Bartonian Middle Eocene 3938 mya'),
#  Document(metadata={}, page_content='977. Passage: Contra Baker et al 2006'),
#  Document(metadata={}, page_content='978. Passage: primitive penguins spread South America process expanding Atlantic waters Clarke et al 2003'),
#  Document(metadata={}, page_content='979. Passage: Late Eocene Early Oligocene 4030 mya lineages gigantic penguins existed Nordenskjoelds Giant Penguin tallest growing nearly 180 meters 6 ft tall New Zealand Giant Penguin probably heaviest weighing 80 kg found New Zealand former also Antarctic farther eastwards'),
#  Document(metadata={}, page_content='980. Passage: Traditionally extinct species penguins giant small placed paraphyletic subfamily called Palaeeudyptinae recently new taxa discovered placed phylogeny possible becoming accepted least 2 major extinct lineages One two closely related ones occurred Patagonia least one includes paleeeudyptines recognized today occurred Antarctic subantarctic coasts'),
#  Document(metadata={}, page_content='981. Passage: size plasticity seems great initial stage penguin radiation Seymour Island Antarctica example around ten known species penguins ranging medium huge size apparently coexisted 35 mya Priabonian Late Eocene Jadwiszczak 2006 even known whether gigantic palaeeudyptines constitute monophyletic lineage whether gigantism evolved independently much restricted Palaeeudyptinae Anthropornithinae considered valid whether wide size range present Palaeeudyptinae delimited usually done days ie including Anthropornis nordenskjoeldi Ksepka et al 2006 oldest welldescribed giant penguin 5foottall Icadyptes salasi actually occurred far north northern Peru 36 mya'),
#  Document(metadata={}, page_content='982. Passage: case gigantic penguins disappeared end Paleogene around 25 mya Interestingly decline disappearance coincides spread Squalodontoidea primitive fisheating toothed whales certainly competed food ultimately successful Baker et al 2006 new lineage Paraptenodytes includes smaller decidedly stoutlegged forms already arisen southernmost South America time early Neogene saw emergence yet another morphotype area similarlysized gracile Palaeospheniscinae well radiation gave rise penguin biodiversity time'),
#  Document(metadata={}, page_content='983. Passage: Modern penguins consititute two undisputed clades another two basal genera ambiguous relationships Bertelli Giannini 2005 origin Spheniscinae lies probably latest Paleogene geographically must much general area order evolved oceans AustraliaNew Zealand region Antarctic Baker et al 2006 Presumedly diverging penguins around 40 mya Baker et al 2006 seems Spheniscinae quite time limited ancestral area wellresearched deposits Antarctic Peninsula Patagonia yielded Paleogene fossils subfamily Also earliest spheniscine lineages southern distribution'),
#  Document(metadata={}, page_content='984. Passage: genus Aptenodytes appears basalmost divergence among living penguins bright yelloworange neck breast bill patches incubate placing eggs feet hatch almost naked genus distribution centered Antarctic coasts barely extends subantarctic islands today'),
#  Document(metadata={}, page_content='985. Passage: Pygoscelis contains species fairly simple blackandwhite head pattern distribution intermediate centered Antarctic coasts extending somewhat northwards external morphology apparently still resemble common ancestor Spheniscinae Aptenodytes autapomorphies cases fairly pronounced adaptations related genus extreme habitat conditions former genus Pygoscelis seems diverged Bartonian'),
#  Document(metadata={}, page_content='986. Passage: fact fairly likely Bartonian nearsynchronous allopatric split ancestors Aptenodytes Pygoscelis common ancestor remaining genera Baker et al 2006'),
#  Document(metadata={}, page_content='987. Passage: range expansion radiation lead presentday diversity probably occur much later around Burdigalian stage Early Miocene roughly 2015 mya Baker et al 2006'),
#  Document(metadata={}, page_content='988. Passage: genera Spheniscus Eudyptula contain species mostly subantarctic distribution centered South America however range quite far northwards lack carotenoid coloration former genus conspicuous banded head pattern unique among living penguins nesting burrows group probably radiated eastwards Antarctic Circumpolar Current ancestral range modern penguins throughout Chattian Late Oligocene starting approximately 28 mya Baker et al 2006 two genera separated time presentday diversity result Pliocene radiation taking place 42 mya Baker et al 2006'),
#  Document(metadata={}, page_content='989. Passage: Megadyptes Eudyptes clade occurs similar latitudes though far north Galapagos Penguin highest diversity New Zealand region represent westward dispersal characterized hairy yellow ornamental head feathers bills least partly red two genera diverged apparently Middle Miocene Langhian roughly 1514 mya living species Eudyptes product later radiation stretching late Tortonian Late Miocene 8 mya end Pliocene Baker et al 2006'),
#  Document(metadata={}, page_content='990. Passage: interesting note geographical temporal pattern spheniscine evolution corresponds closely two episodes global cooling documented paleoclimatic record Baker et al 2006 emergence subantarctic lineage end Bartonian corresponds onset slow period cooling eventually led ice ages 35 million years later habitat Antarctic coasts declining Priabonian hospitable conditions penguins existed subantarctic regions rather Antarctica Notably cold Antarctic Circumpolar Current also started continuous circumpolar flow around 30 mya one hand forcing Antarctic cooling facilitating eastward expansion Spheniscus South America eventually beyond Baker et al 2006'),
#  Document(metadata={}, page_content='991. Passage: Later interspersed period slight warming ended Middle Miocene Climate Transition sharp drop global average temperature 14 12 mya similar abrupt cooling events followed 8 mya 4 mya end Tortonian Antarctic ice sheet already much like today volume extent emergence todays subantarctic penguin species almost certainly caused sequence Neogene climate shifts'),
#  Document(metadata={}, page_content='992. Passage: Penguin ancestry beyond Waimanu remains unknown well resolved molecular morphological analyses latter tend confounded strong adaptive autapomorphies Sphenisciformes sometimes perceived fairly close relationship penguins grebes almost certainly error based groups strong diving adaptations homoplasies hand different DNA sequence datasets agree detail either'),
#  Document(metadata={}, page_content='993. Passage: seems clear penguins belong clade Neoaves living birds except paleognaths fowl comprises sometimes called higher waterbirds distinguish ancient waterfowl group contains birds storks rails seabirds possible exception Charadriiformes Fain Houde 2004'),
#  Document(metadata={}, page_content='994. Passage: Inside group penguin relationships far less clear Depending analysis dataset close relationship Ciconiiformes eg Slack et al 2006 Procellariiformes Baker et al 2006 suggested eg Mayr 2005 think penguinlike plotopterids usually considered relatives anhingas cormorants may actually sister group penguins penguins may ultimately shared common ancestor Pelecaniformes consequently would included order plotopterids close pelecaniforms generally assumed would necessitate splitting traditional Pelecaniformes three'),
#  Document(metadata={}, page_content='995. Passage: Auk Northern Hemisphere superficially similar penguins related penguins considered product moderate convergent evolution Convergence divergence evolution aquatic birds Marcel Van Tuinen Dave Brian Butvill John W Kirsch Blair Hedges'),
#  Document(metadata={}, page_content='996. Passage: word Penguin thought derive Welsh words pen head gwyn white Oxford English Dictionary Accessed March 21 2007 applied Great Auk white spots front eyes although head black island Newfoundland known Pengwyn due large white rock latter case name may also come Breton theory supported fact penguins look remarkably like Great Auks general shape'),
#  Document(metadata={}, page_content='997. Passage: also possible penguin comes Latin pinguis âfatâ supported fact corresponding words languages eg French pingouin German Pinguin instead e first vowel However Welsh often soundshifted e English language'),
#  Document(metadata={}, page_content='998. Passage: Another theory states word alteration âpenwingâ reference rudimentary wings Great Auks penguins evidence'),
#  Document(metadata={}, page_content='999. Passage: Tux Linux kernel mascot'),
#  Document(metadata={}, page_content='1000. Passage: Penguins popular around world primarily unusually upright waddling pace compared birds lack fear humans striking black white plumage often likened tuxedo suit Perhaps reaction cutesy stereotype fictional penguins occasionally presented grouchy even sinister Penguins also subject many books documentary films Happy Feet Surfs CGIAnimated Animal Adventure Films March Penguins documentary based migration process Emperors parody film entitled Farce Penguins Mistakenly artists writers penguins based North Pole incorrect almost wild penguins northern hemisphere barely northernmost GalÃpagos Penguins also found way number cartoons television dramas perhaps notable Pingu created Silvio Mazzola 1986 covering 100 short episodes'),
#  ...]

# %%
len(documents)
# Out:
# 3200

# %%
# insert splits into Pinecone vector database as embeddings
PineconeVectorStore.from_documents(documents, embeddings, index_name=pc_index)

# %%
complete_dataset.to_csv('../data/context_data.csv')
